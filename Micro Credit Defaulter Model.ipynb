# %%
#importing libraries
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
df=pd.read_csv("Data file.csv")
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
#dropping unnamed coloum :
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
# label                   209593 non-null int64
# msisdn                  209593 non-null object
# aon                     209593 non-null float64
# daily_decr30            209593 non-null float64
# daily_decr90            209593 non-null float64
# rental30                209593 non-null float64
# rental90                209593 non-null float64
# last_rech_date_ma       209593 non-null float64
# last_rech_date_da       209593 non-null float64
# last_rech_amt_ma        209593 non-null int64
# cnt_ma_rech30           209593 non-null int64
# fr_ma_rech30            209593 non-null float64
# sumamnt_ma_rech30       209593 non-null float64
# medianamnt_ma_rech30    209593 non-null float64
# medianmarechprebal30    209593 non-null float64
# cnt_ma_rech90           209593 non-null int64
# fr_ma_rech90            209593 non-null int64
# ...

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
#checking shape
df.shape
# Out:
# (209593, 36)

# %%
# checking null values
print(df.isnull().sum())
print(sns.heatmap(df.isnull()))
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
## checking correlation in dataset
print(df.corr())
print(sns.heatmap(df.corr()))
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# ...

# %%
#The data is very less correlated because from the graph their is very less lighter color is showing among the columns.

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
#converting pdate into datetime format 
df['pdate']=pd.to_datetime(df['pdate'])

# %% [markdown]
# # EDA :

# %%
#checking the target variable
# The dataset is imbalanced
#Most of the lablel is bias with label = 1

sns.countplot(df['label'])

# %%
#distplots for some features:
col=['aon','daily_decr30','daily_decr90','rental30','rental90']
for i in col:
    print(i)
    sns.distplot(df[i])
    plt.show()
# Out:
# aon
# daily_decr30
# daily_decr90
# rental30
# rental90

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
# box plot for some columns: for analyzing the outlers:

col=['rental30', 'daily_decr30','last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30', 'amnt_loans30','amnt_loans90', 
     'maxamnt_loans30', 'payback30','payback90']
for i in col:
    print(i)
    sns.boxplot(df[i])
    plt.show()
# Out:
# rental30
# daily_decr30
# last_rech_amt_ma
# cnt_ma_rech30
# fr_ma_rech30
# amnt_loans30
# amnt_loans90
# maxamnt_loans30
# payback30
# payback90

# %%
# from the above boxplots it is clearly visible that too many outliers are there in abouve features:

# %%
# extracting month and year from pdate:
df['month']=df['pdate'].dt.month
df['year']=df['pdate'].dt.year

# %%
sns.barplot(x=df['month'],y=df['aon'],hue=df['label'])

# %%
# above, we can clearly see that there are no defaulter in 8th month

# %%
sns.barplot(x=df['year'],y=df['aon'],hue=df['label'])

# %%
sns.barplot(x='medianamnt_loans90',y='label',data=df)
plt.show()

# %%
sns.barplot(x=df['month'],y=df['daily_decr90'],hue=df['label'])

# %%
sns.barplot(x=df['month'],y=df['daily_decr30'],hue=df['label'])

# %%
sns.lineplot(x=df['month'],y=df['payback90'])

# %%
sns.lineplot(x=df['month'],y=df['payback30'])

# %%
#from above , Most of the users paybacked loan in the month of july and decrease in august month

# %%
sns.countplot(x=df['cnt_loans30'],order=df.cnt_loans30.value_counts().iloc[:11].index)

# %%
#In the above countplot most of the user take loan 1,2 and 3 time only

# %%
sns.countplot(x='amnt_loans30',order=df.amnt_loans30.value_counts().iloc[:11].index,data=df)

# %%
plt.figure(figsize=(18,6))
sns.countplot(x='maxamnt_loans30',order=df.maxamnt_loans30.value_counts().iloc[:11].index,data=df)
plt.show()

# %%
# above shows that maxamnt loans are of 6,12 only

# %%
# pairplot for the first 50 samples only:
sns.pairplot(df.sample(50))

# %% [markdown]
# # Data Preprocessing:

# %%
#dropping columns which have no impact in training the model like pdate , year, month etc-
df.drop(['pdate','month','year','msisdn','pcircle'],inplace=True,axis=1)

# %%
# checking the skewness for the features:
df.skew()
# Out:
# label                   -2.270254
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# medianamnt_loans30       4.551043
# ...

# %%
# after checking the skewness it is clearly visible that most of columns are left skewed also contains too many outlier :

# %% [markdown]
# # #Treating outliers :
# Replacing the outliers with IQR after third deviation
#
# -by doing this data will not be lost much as using zscore large amount of data is lost and we can not afford to lose more than
#  7-8% data

# %%
out_col= ['aon','last_rech_date_ma','last_rech_date_da','fr_ma_rech30','medianmarechprebal30','medianmarechprebal90','cnt_da_rech30','fr_da_rech30','medianmarechprebal90','cnt_da_rech90','maxamnt_loans30','cnt_loans90','sumamnt_ma_rech30','sumamnt_ma_rech90']

# %%
for col in out_col:
    IQR = df[col].quantile(0.75) - df[col].quantile(0.25)
    upper_value=df[col].quantile(0.75)+(IQR*3)
    print("Upper value : ")
    print(col+" : ",upper_value)
    print("\n")
# Out:
# Upper value :
# aon :  3190.0
#
#
# Upper value :
# last_rech_date_ma :  25.0
#
#
# Upper value :
# last_rech_date_da :  0.0
#
#
# Upper value :
# fr_ma_rech30 :  24.0
#
#
# Upper value :
# medianmarechprebal30 :  299.0
#
#
# Upper value :
# medianmarechprebal90 :  273.4400000000005
#
#
# Upper value :
# cnt_da_rech30 :  0.0
#
#
# Upper value :
# fr_da_rech30 :  0.0
#
#
# Upper value :
# medianmarechprebal90 :  273.4400000000005
#
#
# Upper value :
# cnt_da_rech90 :  0.0
#
#
# Upper value :
# maxamnt_loans30 :  6.0
#
#
# Upper value :
# cnt_loans90 :  17.0
#
#
# Upper value :
# sumamnt_ma_rech30 :  35420.0
#
#
# Upper value :
# sumamnt_ma_rech90 :  57049.0

# %%
df.loc[df['aon']>=3190,'aon']=3190
df.loc[df['last_rech_date_ma']>=25,'last_rech_date_ma']=25
df.loc[df['last_rech_date_da']>=20,'last_rech_date_da']=0
df.loc[df['fr_ma_rech30']>=24,'fr_ma_rech30']=24
df.loc[df['medianmarechprebal30']>=299,'medianmarechprebal30']=299
df.loc[df['medianmarechprebal90']>=274,'medianmarechprebal90']=274
df.loc[df['cnt_da_rech30']>=4,'cnt_da_rech30']=4
df.loc[df['fr_da_rech30']>=9,'fr_da_rech30']=0
df.loc[df['maxamnt_loans30']>12,'maxamnt_loans30']=0
df.loc[df['cnt_loans90']>=17,'cnt_loans90']=17
df.loc[df['sumamnt_ma_rech90']>=57049,'sumamnt_ma_rech90']=57049
df.loc[df['sumamnt_ma_rech30']>=35420,'sumamnt_ma_rech30']=35420

# %%
df.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 0                2.0                0.0              1539              2  ...
# 1               20.0                0.0              5787              1  ...
# 2                3.0                0.0              1539              1  ...
# 3               25.0                0.0               947              0  ...
# 4                4.0                0.0              2309              7  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# ...

# %%
df.shape
# Out:
# (209593, 33)

# %%
# splitting the features and target variables:
x=df.drop('label',axis=1)
y=df['label']

# %% [markdown]
# # # Feature selection :
# with the following function we can select highly correlated features
#
# And we can remove such columns having less impact on the dataset :

# %%
plt.figure(figsize=(30,30))
sns.heatmap(x.corr(),annot=True)
plt.plot()
# Out:
# []

# %%
# from the above corrleation heatmp it is shown that some features are postively correlated with more than 80 percent
# dropping these features :

# %%
x.drop(['cnt_loans90', 'cnt_ma_rech90', 'daily_decr90','medianamnt_loans90', 'medianamnt_ma_rech90'],axis=1,inplace=True)

# %% [markdown]
# # # Feature scaling :

# %%
# scaling using standard scaler :
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x=pd.DataFrame(x,columns=df.columns[1:28])

# %%
x.head(4)
# Out:
#         aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0 -0.732987     -0.252299     -0.573844 -0.558583 -0.484771
# 1  0.056834      0.731037      0.231788  0.036020  2.107784
# 2 -0.260889     -0.432011     -0.416020 -0.447674 -0.340741
# 3 -0.788634     -0.581326     -0.587935 -0.576036  2.827938
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0          -0.088853          -0.221637         -0.464760       3.131216
# 1          -0.088853           1.570178         -0.699718      -0.727171
# 2          -0.088853          -0.221637         -0.699718      -0.727171
# 3          -0.088853          -0.471344         -0.934677      -0.727171
#
#    fr_ma_rech30  ...  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0     -0.534268  ...             -0.104375      -0.048048     -0.297116
# 1     -0.194272  ...             -0.104375      -0.048048     -0.688582
# 2     -0.727422  ...             -0.104375      -0.048048     -0.688582
# ...

# %%
y=df['label']
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 209593, dtype: int64

# %%
y['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
from sklearn.utils import resample

# %%
y=y_downsampled.label

# %% [markdown]
# # Model Building :

# %%
# IMPORTING model building libraries :
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression,Lasso
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,RandomForestClassifier,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score,train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,auc,f1_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # # hyper-parameter tuning :

# %%
# random forest calssifier
rfr=RandomForestClassifier()
parameters={'n_estimators':[1,10,50,100]}
clfr=GridSearchCV(rfr,parameters ,scoring='accuracy', cv=10)
clfr.fit(x,y)
clfr.best_params_
# Out:
# {'n_estimators': 100}

# %%
## decision tree classifier
dtc=DecisionTreeClassifier()
param={'criterion':['gini','entropy']}
clf=GridSearchCV(dtc,param)
clf.fit(x,y)
clf.best_params_
# Out:
# {'criterion': 'entropy'}

# %%
# AdaBoostClassifier 
ada=AdaBoostClassifier()
parameters={'n_estimators':[10,20,50,100],'learning_rate':[0.001,0.01,0.1]}
clf=GridSearchCV(ada,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
# LogisticRegression
lg=LogisticRegression()
grid={'C':10.0 **np.arange(-2,3),'penalty':['l1','l2']}
clf=GridSearchCV(lg,grid)
clf.fit(x,y)
clf.best_params_
# Out:
# {'C': 100.0, 'penalty': 'l2'}

# %%
# finging the best Random state for the model at which the accuracy score must be highest :

# %%
def max_acc_Score(classifier,x_new,y):
    max_r_score=0
    for r_state in range(42,90):
        x_train, x_test, y_train, y_test=train_test_split(x_new,y,random_state=r_state,test_size=0.22)
        classifier.fit(x_train,y_train)
        y_pred=classifier.predict(x_test)
        acc_scr=accuracy_score(y_test,y_pred)
        print('accuracy score corr to random state',r_state,'is:',acc_scr)
        if acc_scr>max_r_score:
            max_r_score=acc_scr
            final_r_state=r_state
    print()
    print()
    print("max acc score corr to ",final_r_state,'is',max_r_score)       
    return final_r_state

# %%
#finding best rstate and acc score  for random forest classifier:
rfc=RandomForestClassifier(n_estimators=100)
r_state=max_acc_Score(rfc,x,y)
# Out:
# accuracy score corr to random state 42 is: 0.9118214742686127
# accuracy score corr to random state 43 is: 0.9115178590791785
# accuracy score corr to random state 44 is: 0.9123419574504998
# accuracy score corr to random state 45 is: 0.9134479842120101
# accuracy score corr to random state 46 is: 0.9117347270716315
# accuracy score corr to random state 47 is: 0.909739541541064
# accuracy score corr to random state 48 is: 0.9125805122421982
# accuracy score corr to random state 49 is: 0.9130142482271042
# accuracy score corr to random state 50 is: 0.9131009954240854
# accuracy score corr to random state 51 is: 0.9130359350263495
# accuracy score corr to random state 52 is: 0.9124720782459717
# accuracy score corr to random state 53 is: 0.9099130359350264
# accuracy score corr to random state 54 is: 0.9132094294203118
# accuracy score corr to random state 55 is: 0.9137515994014443
# accuracy score corr to random state 56 is: 0.9126672594391794
# ...

# %%
# splitting into train test data :
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=89)

# %%
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (167674, 27) (41919, 27)
# (167674,) (41919,)

# %%
# models using for the training :
# tuned the parameters for the best results:

rfc=RandomForestClassifier(n_estimators=100)
lg=LogisticRegression(penalty='l2')
knn=KNeighborsClassifier(n_neighbors=9)
ada=AdaBoostClassifier(learning_rate=0.1,n_estimators=100)
gbc=GradientBoostingClassifier(n_estimators=100)
dtc=DecisionTreeClassifier(criterion='entropy')

# %%
models = []
models.append(('randomforestclassifier', rfc))
models.append(('logistic regression', lg))
models.append(('ada boost classifier', ada))
models.append(('gradient boosting classifier', gbc))
models.append(('decisiontreeclassifier', dtc))
models.append(('kneighborsclassifier', knn))

# %%
# Calling out the accuracy score , auc roc score , cross validation score and the classification metrices for the models :
Model = []
score = []
cvs=[]
rocscore=[]
F1score=[]
for name,model in models:
    print('*******************',name,'*******************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_Score = ',AS)
    score.append(AS*100)
    print('\n')
    f1 = f1_score(y_test,pre)
    print("f1 score: ",f1)
    F1score.append(f1*100)
    print('\n')
    sc = cross_val_score(model, x, y, cv=10, scoring='accuracy').mean()
    print('Cross_Val_Score = ',sc)
    cvs.append(sc*100)
    print('\n')
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,pre)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    print('\n')
    print('Classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')  
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate, true_positive_rate, label='AUC = %0.2f'% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# ******************* randomforestclassifier *******************
#
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
# Accuracy_Score =  0.9126649013573797
#
#
# f1 score:  0.9516143954112314
#
#
# Cross_Val_Score =  0.912454137518445
#
#
#
#
# Classification_report
#                precision    recall  f1-score   support
#
#            0       0.77      0.43      0.55      5238
#            1       0.92      0.98      0.95     36681
#
#     accuracy                           0.91     41919
# ...

# %%
# displaying the results into a dataframe :

result=pd.DataFrame({'model':Model,'F1 score':F1score,'Accu_score':score,'cross_val_Score':cvs})
result
# Out:
#                           model   F1 score  Accu_score  cross_val_Score
# 0        randomforestclassifier  95.161440   91.266490        91.245414
# 1           logistic regression  93.318822   87.552184        87.575445
# 2          ada boost classifier  94.697648   90.250245        90.153774
# 3  gradient boosting classifier  95.009954   90.911043        90.852748
# 4        decisiontreeclassifier  92.536133   86.941482        86.795834
# 5          kneighborsclassifier  93.437938   88.167657        88.189970

# %% [raw]
# # So  from the above results , it is visible that "Random Forest" algorithm is giving the less false positive rate among all others algorithm and performing best amongst all with  high accuracy and cross validation scores but there is some inbalance in the random forest algorithm as the recall value seems to be imbalance but decision tree seems to be performing better than random forest on recall terms and less imbalanced:

# %%
# predicting results using that :
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(x_train,y_train)
pred = rfc.predict(x_test)
ac_score = accuracy_score(y_test,pred)
f1 = f1_score(y_test,pred)
print("f1 score :",f1)
print('\n') 
print('Accuracy Score :',ac_score*100)
print('\n') 
print('cross validation score :',cross_val_score(rfc, x, y, cv=10, scoring='accuracy').mean())
print('\n')
print('confusion matrix :',confusion_matrix(y_test,pred))
print('\n') 
print('Classification report :',classification_report(y_test,pred))
# Out:
# f1 score : 0.951710288152836
#
#
# Accuracy Score : 91.28080345428089
#
#
# cross validation score : 0.9127356379049726
#
#
# confusion matrix : [[ 2247  2991]
#  [  664 36017]]
#
#
# Classification report :               precision    recall  f1-score   support
#
#            0       0.77      0.43      0.55      5238
#            1       0.92      0.98      0.95     36681
#
#     accuracy                           0.91     41919
#    macro avg       0.85      0.71      0.75     41919
# weighted avg       0.90      0.91      0.90     41919

# %%
# predicting results using that :
dtc = DecisionTreeClassifier(criterion='entropy')
dtc.fit(x_train,y_train)
pred = dtc.predict(x_test)
ac_score = accuracy_score(y_test,pred)
f1 = f1_score(y_test,pred)
print("f1 score :",f1)
print('\n') 
print('Accuracy Score :',ac_score*100)
print('\n') 
print('cross validation score :',cross_val_score(dtc, x, y, cv=10, scoring='accuracy').mean())
print('\n')
print('confusion matrix :',confusion_matrix(y_test,pred))
print('\n') 
print('Classification report :',classification_report(y_test,pred))
# Out:
# f1 score : 0.9252526354548802
#
#
# Accuracy Score : 86.92478351105703
#
#
# cross validation score : 0.8678724742448416
#
#
# confusion matrix : [[ 2515  2723]
#  [ 2758 33923]]
#
#
# Classification report :               precision    recall  f1-score   support
#
#            0       0.48      0.48      0.48      5238
#            1       0.93      0.92      0.93     36681
#
#     accuracy                           0.87     41919
#    macro avg       0.70      0.70      0.70     41919
# weighted avg       0.87      0.87      0.87     41919

# %%
pred_prob = rfc.predict_proba(x_test)[:,1]
pred_prob
# Out:
# array([0.52, 1.  , 0.94, ..., 0.88, 0.99, 0.93])

# %%
fpr,tpr,thresholds = roc_curve(y_test,pred_prob)
print(fpr)
print("\n")
print(tpr)
print("\n")
print(thresholds)
# Out:
# [0.         0.01088202 0.02405498 0.04085529 0.05651012 0.06911035
#  0.06911035 0.0836197  0.0836197  0.09812906 0.09812906 0.1093929
#  0.12485682 0.12485682 0.13993891 0.13993891 0.1534937  0.1534937
#  0.16475754 0.17983963 0.17983963 0.18003055 0.19683085 0.19702176
#  0.19702176 0.21229477 0.21229477 0.22546774 0.22565865 0.22565865
#  0.22584956 0.24264987 0.24264987 0.24284078 0.24284078 0.25505918
#  0.25505918 0.27090493 0.27090493 0.27128675 0.28388698 0.28407789
#  0.29591447 0.30889653 0.30889653 0.30908744 0.32016037 0.33256968
#  0.33295151 0.33314242 0.33314242 0.34421535 0.34421535 0.35777014
#  0.35777014 0.36788851 0.36788851 0.36807942 0.37896144 0.37896144
#  0.37915235 0.39022528 0.39041619 0.39041619 0.40110729 0.40110729
#  0.41294387 0.41313478 0.42153494 0.42153494 0.43127148 0.43146239
#  0.44158076 0.44902635 0.45532646 0.45532646 0.46429935 0.47212677
#  0.47231768 0.48052692 0.48892707 0.48911798 0.49809087 0.49809087
# ...

# %%
#Plotting the graph which tells us about the area under curve , more the area under curve more will be the better prediction
# model is performing good :
plt.plot([0,1],[1,0],'k--')
plt.plot(fpr,tpr,label = 'RandomForestClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('RandomForestClassifier')
plt.show()

# %%
pred_prob = dtc.predict_proba(x_test)[:,1]
pred_prob
# Out:
# array([0., 1., 1., ..., 1., 1., 1.])

# %%
fpr,tpr,thresholds = roc_curve(y_test,pred_prob)
print(fpr)
print("\n")
print(tpr)
print("\n")
print(thresholds)
# Out:
# [0.         0.51985491 0.51985491 0.52157312 0.52214586 0.52233677
#  0.52271859 0.52290951 1.        ]
#
#
# [0.         0.92478395 0.92481121 0.92492026 0.92494752 0.92494752
#  0.92494752 0.92494752 1.        ]
#
#
# [2.         1.         0.66666667 0.5        0.33333333 0.25
#  0.2        0.14285714 0.        ]

# %%
#Plotting the graph which tells us about the area under curve , more the area under curve more will be the better prediction
# model is performing good :
plt.plot([0,1],[1,0],'k--')
plt.plot(fpr,tpr,label = 'decision tree Classifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('decision tree Classifier')
plt.show()

# %%
#save the model as a pickel in a file
from sklearn.externals import joblib
joblib.dump(dtc,'Micro-Credit Defaulter Model.pkl')
# Out:
# C:\Users\prince\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['Micro-Credit Defaulter Model.pkl']
